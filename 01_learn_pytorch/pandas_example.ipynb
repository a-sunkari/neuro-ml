# %% [markdown]
# # Add imports

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("example_data.csv")  # columns: subject, group, age, sex, mean_fd
print(df.head())

df['age'].hist()

plt.xlabel('Age')
plt.ylabel('Count')
plt.title('Age distribution')
plt.show()
# Out:
#   subject group  age sex  mean_fd
# 0    alex  cold   18   m     0.11
# 1     tim  warm   24   m     0.82
# 2   sarah  cold   16   f     0.20
# 3     jim  warm   18   m     0.83
# 4    izzy  cold   37   f     0.30
